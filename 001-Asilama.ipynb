# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
dataFrame = pd.read_csv("vaccination-data.csv")

# %%
dataFrame
# Out:
#                COUNTRY ISO3 WHO_REGION DATA_SOURCE DATE_UPDATED  \
# 0          Afghanistan  AFG       EMRO   REPORTING   2023-05-29
# 1              Albania  ALB       EURO   REPORTING   2023-05-14
# 2              Algeria  DZA       AFRO   REPORTING   2022-09-04
# 3       American Samoa  ASM       WPRO   REPORTING   2023-03-29
# 4              Andorra  AND       EURO   REPORTING   2023-04-09
# ..                 ...  ...        ...         ...          ...
# 224           Viet Nam  VNM       WPRO   REPORTING   2023-05-25
# 225  Wallis and Futuna  WLF       WPRO   REPORTING   2023-01-23
# 226              Yemen  YEM       EMRO   REPORTING   2023-04-18
# 227             Zambia  ZMB       AFRO   REPORTING   2023-04-09
# 228           Zimbabwe  ZWE       AFRO   REPORTING   2023-05-14
#
#      TOTAL_VACCINATIONS  PERSONS_VACCINATED_1PLUS_DOSE  \
# 0            18434710.0                       15875256
# 1             3080679.0                        1348396
# ...

# %%
avrupa = dataFrame[dataFrame["WHO_REGION"] == "EURO"]

# %%
avrupa
# Out:
#                     COUNTRY ISO3 WHO_REGION DATA_SOURCE DATE_UPDATED  \
# 1                   Albania  ALB       EURO   REPORTING   2023-05-14
# 4                   Andorra  AND       EURO   REPORTING   2023-04-09
# 9                   Armenia  ARM       EURO   REPORTING   2023-05-14
# 12                  Austria  AUT       EURO   REPORTING   2023-05-14
# 13               Azerbaijan  AZE       EURO   REPORTING   2023-05-14
# 18                  Belarus  BLR       EURO   REPORTING   2023-04-16
# 19                  Belgium  BEL       EURO   REPORTING   2023-05-14
# 27   Bosnia and Herzegovina  BIH       EURO   REPORTING   2022-01-29
# 32                 Bulgaria  BGR       EURO   REPORTING   2023-05-14
# 50                  Croatia  HRV       EURO   REPORTING   2023-05-14
# 53                   Cyprus  CYP       EURO   REPORTING   2023-05-14
# 54                  Czechia  CZE       EURO   REPORTING   2023-05-14
# 56                  Denmark  DNK       EURO   REPORTING   2023-05-14
# ...

# %%
filtrelenmis_avrupa = avrupa[["ISO3","TOTAL_VACCINATIONS"]]

# %%
filtrelenmis_avrupa = filtrelenmis_avrupa.rename(columns={"ISO3":"ISO3_CODE"})

# %%
filtrelenmis_avrupa
# Out:
#     ISO3_CODE  TOTAL_VACCINATIONS
# 1         ALB           3080679.0
# 4         AND            157038.0
# 9         ARM           2156999.0
# 12        AUT          20401515.0
# 13        AZE          13822539.0
# 18        BLR          21205264.0
# 19        BEL          29117995.0
# 27        BIH           1924950.0
# 32        BGR           4617676.0
# 50        HRV           5432534.0
# 53        CYP           1858796.0
# 54        CZE          18614118.0
# 56        DNK          15002820.0
# 65        EST           2204078.0
# 69        FRO            103894.0
# 71        FIN          13261002.0
# 72        FRA         158014193.0
# 77        GEO           2738178.0
# 78        DEU         193232623.0
# 80        GIB            132810.0
# 81        GRC          21982946.0
# 82        GRL             79738.0
# 87        GGY            178525.0
# 93        HUN          16569954.0
# 94        ISL            869976.0
# 99        IRL          12377654.0
# ...

# %%
fig, ax = plt.subplots(figsize =(10,6))# Figure ve axes oluşturun
# DataFrame'i tablo olarak gösterin
table = plt.table(cellText=filtrelenmis_avrupa.values,# DataFrame'in değerlerini kullanın
                 colLabels=filtrelenmis_avrupa.columns,# Sütun başlıklarını kullanın
                 cellLoc='center',# Hücre içeriğini ortala
                 loc='center')# Tabloyu ortala
# Tabloyu düzenleme
table.auto_set_font_size(False)
table.set_fontsize(12)
table.scale(1.2,1.2)# Tablo boyutunu ayarlayın

ax.axis('off')# Eksenleri ve çerçeveyi gizle
# Out:
# (0.0, 1.0, 0.0, 1.0)

# %%
fig, ax = plt.subplots(figsize=(10,6)) # Figure ve axes oluşturun
x = filtrelenmis_avrupa["ISO3_CODE"] # x eksenine ülke isimlerini alın
y = filtrelenmis_avrupa["TOTAL_VACCINATIONS"] # y eksenine toplam aşılama verilerini alın

ax.bar(x,y) # Çubuk grafik oluşturun
# Eksen ve başlık etiketlerini ekleyin
ax.set_xlabel("Ülkeler")
ax.set_ylabel("Toplam Aşılama(milyon)")
ax.set_title("Euro Bölgesi Ülkelerde Toplam Aşılama")
# x ekseni etiketlerini döndürün ve sıkıştırın
plt.xticks(rotation=90)
plt.tight_layout()
